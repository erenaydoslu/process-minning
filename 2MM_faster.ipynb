# %%
import pandas as pd
import numpy as np
import datetime
import random
import time
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
import matplotlib.pyplot as plt
from collections import Counter
from tqdm import tqdm, trange
import copy

# %%
def fix_time(time):
    return (datetime.datetime.fromisoformat(time))

def load_data(BPI = 'BPI.csv', BPI_attr = 'BPI_attr.csv',  data2012 = False, sample=False):
    df_BPI = pd.read_csv(BPI)
    df_BPI_attr = pd.read_csv(BPI_attr)
    
    if 'Unnamed: 0' in df_BPI.columns:
        df_BPI = df_BPI.rename(columns={'Unnamed: 0': 'case_id', 'Unnamed: 1': 'step_number'})
        df_BPI_attr = df_BPI_attr.rename(columns={'Unnamed: 0': 'case_id'})
    
    df_BPI['time:timestamp'] = df_BPI['time:timestamp'].apply(fix_time)

    df_BPI_attr['REG_DATE'] = df_BPI_attr['REG_DATE'].apply(fix_time)
    
    df_BPI['time:weekday'] = [x.weekday() for x in df_BPI['time:timestamp']]
    df_BPI['time:hour'] = [x.hour for x in df_BPI['time:timestamp']]
    
    if(sample):
        df_BPI, df_BPI_attr = df_BPI[:50000], df_BPI_attr[:2359]
    
    return (df_BPI, df_BPI_attr)
    return (df_BPI, df_BPI_attr)

def load_data_xes(data):
    BPI = xes_importer.apply(data)
    
df, df_attr = load_data(BPI = 'Datasets\BPI_2012.csv', BPI_attr = 'Datasets\BPI_attr_2012.csv', sample=False)

# %%
df_markov = copy.deepcopy(df)
df_markov['combined_names'] = df_markov['lifecycle:transition'] + ' + ' + df_markov['concept:name']
df_markov
# Out:
#         case_id  step_number  org:resource lifecycle:transition  \
# 0             0            0         112.0             COMPLETE
# 1             0            1         112.0             COMPLETE
# 2             0            2         112.0             COMPLETE
# 3             0            3         112.0             SCHEDULE
# 4             0            4           NaN                START
# 5             0            5       10862.0             COMPLETE
# 6             0            6       10862.0             COMPLETE
# 7             0            7       10862.0             COMPLETE
# 8             0            8       10862.0             COMPLETE
# 9             0            9       10862.0             COMPLETE
# 10            0           10           NaN             SCHEDULE
# 11            0           11           NaN             COMPLETE
# 12            0           12           NaN                START
# 13            0           13           NaN             COMPLETE
# 14            0           14       10913.0                START
# 15            0           15       10913.0             COMPLETE
# 16            0           16       11049.0                START
# 17            0           17       11049.0             COMPLETE
# 18            0           18       11049.0             SCHEDULE
# 19            0           19       11049.0             COMPLETE
# 20            0           20       10629.0                START
# 21            0           21       10629.0             COMPLETE
# 22            0           22       10629.0             COMPLETE
# 23            0           23       10629.0             COMPLETE
# 24            0           24       10629.0             COMPLETE
# 25            0           25       10629.0             COMPLETE
# 26            1            0         112.0             COMPLETE
# 27            1            1         112.0             COMPLETE
# 28            1            2         112.0             COMPLETE
# 29            1            3         112.0             SCHEDULE
# ...         ...          ...           ...                  ...
# 262170    13083            2         112.0             COMPLETE
# 262171    13084            0         112.0             COMPLETE
# 262172    13084            1         112.0             COMPLETE
# 262173    13084            2         112.0             SCHEDULE
# 262174    13084            3       11169.0                START
# 262175    13084            4       11169.0             COMPLETE
# 262176    13084            5       11169.0             COMPLETE
# 262177    13085            0         112.0             COMPLETE
# 262178    13085            1         112.0             COMPLETE
# 262179    13085            2         112.0             SCHEDULE
# 262180    13085            3       11169.0                START
# 262181    13085            4       11169.0             COMPLETE
# 262182    13085            5       11169.0             SCHEDULE
# 262183    13085            6       11169.0             COMPLETE
# 262184    13085            7       10933.0                START
# 262185    13085            8       10933.0             COMPLETE
# 262186    13085            9       10933.0             COMPLETE
# 262187    13085           10       10933.0             COMPLETE
# 262188    13085           11       10933.0             COMPLETE
# 262189    13085           12       10933.0             COMPLETE
# 262190    13085           13       10933.0             SCHEDULE
# 262191    13085           14       10933.0             COMPLETE
# 262192    13085           15       11119.0                START
# 262193    13085           16       11119.0             COMPLETE
# 262194    13086            0         112.0             COMPLETE
# 262195    13086            1         112.0             COMPLETE
# 262196    13086            2         112.0             SCHEDULE
# 262197    13086            3       11169.0                START
# 262198    13086            4       11169.0             COMPLETE
# 262199    13086            5       11169.0             COMPLETE
#
#                   concept:name                    time:timestamp  \
# 0                  A_SUBMITTED  2011-10-01 00:38:44.546000+02:00
# 1            A_PARTLYSUBMITTED  2011-10-01 00:38:44.880000+02:00
# 2                A_PREACCEPTED  2011-10-01 00:39:37.906000+02:00
# 3       W_Completeren aanvraag  2011-10-01 00:39:38.875000+02:00
# 4       W_Completeren aanvraag  2011-10-01 11:36:46.437000+02:00
# 5                   A_ACCEPTED  2011-10-01 11:42:43.308000+02:00
# 6                   O_SELECTED  2011-10-01 11:45:09.243000+02:00
# 7                  A_FINALIZED  2011-10-01 11:45:09.243000+02:00
# 8                    O_CREATED  2011-10-01 11:45:11.197000+02:00
# 9                       O_SENT  2011-10-01 11:45:11.380000+02:00
# 10         W_Nabellen offertes  2011-10-01 11:45:11.554000+02:00
# 11      W_Completeren aanvraag  2011-10-01 11:45:13.917000+02:00
# 12         W_Nabellen offertes  2011-10-01 12:15:41.290000+02:00
# 13         W_Nabellen offertes  2011-10-01 12:17:08.924000+02:00
# 14         W_Nabellen offertes  2011-10-08 16:26:57.720000+02:00
# 15         W_Nabellen offertes  2011-10-08 16:32:00.886000+02:00
# 16         W_Nabellen offertes  2011-10-10 11:32:22.495000+02:00
# 17                 O_SENT_BACK  2011-10-10 11:33:03.668000+02:00
# 18        W_Valideren aanvraag  2011-10-10 11:33:04.560000+02:00
# 19         W_Nabellen offertes  2011-10-10 11:33:05.791000+02:00
# 20        W_Valideren aanvraag  2011-10-13 10:05:26.925000+02:00
# 21                A_REGISTERED  2011-10-13 10:37:29.226000+02:00
# 22                  A_APPROVED  2011-10-13 10:37:29.226000+02:00
# 23                  O_ACCEPTED  2011-10-13 10:37:29.226000+02:00
# 24                 A_ACTIVATED  2011-10-13 10:37:29.226000+02:00
# 25        W_Valideren aanvraag  2011-10-13 10:37:37.026000+02:00
# 26                 A_SUBMITTED  2011-10-01 08:08:58.256000+02:00
# 27           A_PARTLYSUBMITTED  2011-10-01 08:09:02.195000+02:00
# 28               A_PREACCEPTED  2011-10-01 08:09:56.648000+02:00
# 29      W_Completeren aanvraag  2011-10-01 08:09:59.578000+02:00
# ...                        ...                               ...
# 262170              A_DECLINED  2012-02-29 23:29:21.958000+01:00
# 262171             A_SUBMITTED  2012-02-29 23:28:55.349000+01:00
# 262172       A_PARTLYSUBMITTED  2012-02-29 23:28:55.479000+01:00
# 262173      W_Afhandelen leads  2012-02-29 23:29:06.452000+01:00
# 262174      W_Afhandelen leads  2012-03-01 09:25:39.409000+01:00
# 262175              A_DECLINED  2012-03-01 09:28:18.168000+01:00
# 262176      W_Afhandelen leads  2012-03-01 09:28:21.228000+01:00
# 262177             A_SUBMITTED  2012-02-29 23:43:09.766000+01:00
# 262178       A_PARTLYSUBMITTED  2012-02-29 23:43:09.899000+01:00
# 262179      W_Afhandelen leads  2012-02-29 23:43:54.276000+01:00
# 262180      W_Afhandelen leads  2012-03-01 09:25:47.680000+01:00
# 262181           A_PREACCEPTED  2012-03-01 09:27:50.503000+01:00
# 262182  W_Completeren aanvraag  2012-03-01 09:27:50.551000+01:00
# 262183      W_Afhandelen leads  2012-03-01 09:27:52.388000+01:00
# 262184  W_Completeren aanvraag  2012-03-01 20:11:14.761000+01:00
# 262185              A_ACCEPTED  2012-03-01 20:17:22.457000+01:00
# 262186              O_SELECTED  2012-03-01 20:22:38.593000+01:00
# 262187             A_FINALIZED  2012-03-01 20:22:38.593000+01:00
# 262188               O_CREATED  2012-03-01 20:22:40.016000+01:00
# 262189                  O_SENT  2012-03-01 20:22:40.043000+01:00
# 262190     W_Nabellen offertes  2012-03-01 20:22:40.149000+01:00
# 262191  W_Completeren aanvraag  2012-03-01 20:22:41.157000+01:00
# 262192     W_Nabellen offertes  2012-03-10 12:46:22.700000+01:00
# 262193     W_Nabellen offertes  2012-03-10 12:50:54.881000+01:00
# 262194             A_SUBMITTED  2012-02-29 23:51:16.799000+01:00
# 262195       A_PARTLYSUBMITTED  2012-02-29 23:51:17.423000+01:00
# 262196      W_Afhandelen leads  2012-02-29 23:52:01.287000+01:00
# 262197      W_Afhandelen leads  2012-03-01 09:26:46.736000+01:00
# 262198              A_DECLINED  2012-03-01 09:27:37.118000+01:00
# 262199      W_Afhandelen leads  2012-03-01 09:27:41.325000+01:00
#
#         time:weekday  time:hour                     combined_names
# 0                  5          0             COMPLETE + A_SUBMITTED
# 1                  5          0       COMPLETE + A_PARTLYSUBMITTED
# 2                  5          0           COMPLETE + A_PREACCEPTED
# 3                  5          0  SCHEDULE + W_Completeren aanvraag
# 4                  5         11     START + W_Completeren aanvraag
# 5                  5         11              COMPLETE + A_ACCEPTED
# 6                  5         11              COMPLETE + O_SELECTED
# 7                  5         11             COMPLETE + A_FINALIZED
# 8                  5         11               COMPLETE + O_CREATED
# 9                  5         11                  COMPLETE + O_SENT
# 10                 5         11     SCHEDULE + W_Nabellen offertes
# 11                 5         11  COMPLETE + W_Completeren aanvraag
# 12                 5         12        START + W_Nabellen offertes
# 13                 5         12     COMPLETE + W_Nabellen offertes
# 14                 5         16        START + W_Nabellen offertes
# 15                 5         16     COMPLETE + W_Nabellen offertes
# 16                 0         11        START + W_Nabellen offertes
# 17                 0         11             COMPLETE + O_SENT_BACK
# 18                 0         11    SCHEDULE + W_Valideren aanvraag
# 19                 0         11     COMPLETE + W_Nabellen offertes
# 20                 3         10       START + W_Valideren aanvraag
# 21                 3         10            COMPLETE + A_REGISTERED
# 22                 3         10              COMPLETE + A_APPROVED
# 23                 3         10              COMPLETE + O_ACCEPTED
# 24                 3         10             COMPLETE + A_ACTIVATED
# 25                 3         10    COMPLETE + W_Valideren aanvraag
# 26                 5          8             COMPLETE + A_SUBMITTED
# 27                 5          8       COMPLETE + A_PARTLYSUBMITTED
# 28                 5          8           COMPLETE + A_PREACCEPTED
# 29                 5          8  SCHEDULE + W_Completeren aanvraag
# ...              ...        ...                                ...
# 262170             2         23              COMPLETE + A_DECLINED
# 262171             2         23             COMPLETE + A_SUBMITTED
# 262172             2         23       COMPLETE + A_PARTLYSUBMITTED
# 262173             2         23      SCHEDULE + W_Afhandelen leads
# 262174             3          9         START + W_Afhandelen leads
# 262175             3          9              COMPLETE + A_DECLINED
# 262176             3          9      COMPLETE + W_Afhandelen leads
# 262177             2         23             COMPLETE + A_SUBMITTED
# 262178             2         23       COMPLETE + A_PARTLYSUBMITTED
# 262179             2         23      SCHEDULE + W_Afhandelen leads
# 262180             3          9         START + W_Afhandelen leads
# 262181             3          9           COMPLETE + A_PREACCEPTED
# 262182             3          9  SCHEDULE + W_Completeren aanvraag
# 262183             3          9      COMPLETE + W_Afhandelen leads
# 262184             3         20     START + W_Completeren aanvraag
# 262185             3         20              COMPLETE + A_ACCEPTED
# 262186             3         20              COMPLETE + O_SELECTED
# 262187             3         20             COMPLETE + A_FINALIZED
# 262188             3         20               COMPLETE + O_CREATED
# 262189             3         20                  COMPLETE + O_SENT
# 262190             3         20     SCHEDULE + W_Nabellen offertes
# 262191             3         20  COMPLETE + W_Completeren aanvraag
# 262192             5         12        START + W_Nabellen offertes
# 262193             5         12     COMPLETE + W_Nabellen offertes
# 262194             2         23             COMPLETE + A_SUBMITTED
# 262195             2         23       COMPLETE + A_PARTLYSUBMITTED
# 262196             2         23      SCHEDULE + W_Afhandelen leads
# 262197             3          9         START + W_Afhandelen leads
# 262198             3          9              COMPLETE + A_DECLINED
# 262199             3          9      COMPLETE + W_Afhandelen leads
#
# [262200 rows x 9 columns]

# %%
chain = {}
shape = df_markov.shape[0]
conceptNames = ['editor: first event'] + list(df_markov['combined_names'])
ids = ['editor: first id'] + list(df_markov['case_id']) #Otherwise we check i+1-th position that does not exist


for i, key1 in enumerate(conceptNames):
    
    if shape > i + 2:
        key2 = conceptNames[i+1]
        event = conceptNames[i+2]

        
        if (ids[i] == ids[i+2]): 
            
            if ((key1, key2) not in chain):
                chain[(key1, key2)] = [event] 
            else:
                chain[(key1, key2)].append(event)
                
        elif (event == 'COMPLETE + A_SUBMITTED'): 
            
            if ((key1, key2) not in chain):
                chain[(key1, key2)] = ['editor: close_case']
            else:
                chain[(key1, key2)].append('editor: close_case')
        
        elif (key2 == 'COMPLETE + A_SUBMITTED'):
            
            if ((key1, key2) not in chain):
                chain[(key1, key2)] = ['COMPLETE + A_PARTLYSUBMITTED']
            else:
                chain[(key1, key2)].append('COMPLETE + A_PARTLYSUBMITTED')
        

            
print('Chain size: {0} distinct event pairs.'.format(len(chain)))
chain
# Out:
# Chain size: 202 distinct event pairs.
# {('editor: first event',
#   'COMPLETE + A_SUBMITTED'): ['COMPLETE + A_PARTLYSUBMITTED'],
#  ('COMPLETE + A_SUBMITTED',
#   'COMPLETE + A_PARTLYSUBMITTED'): ['COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Beoordelen fraude',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Beoordelen fraude',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Beoordelen fraude',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Beoordelen fraude',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Beoordelen fraude',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Beoordelen fraude',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'SCHEDULE + W_Afhandelen leads',
#   'SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   'COMPLETE + A_PREACCEPTED',
#   ...],
#  ('COMPLETE + A_PARTLYSUBMITTED',
#   'COMPLETE + A_PREACCEPTED'): ['SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE + W_Completeren aanvraag', 'SCHEDULE ...
#  ('COMPLETE + A_PREACCEPTED',
#   'SCHEDULE + W_Completeren aanvraag'): ['START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'START + W_Completeren aanvraag', 'START + W_Completeren aanvraag', 'START + W_Completeren ...
#  ('SCHEDULE + W_Completeren aanvraag',
#   'START + W_Completeren aanvraag'): ['COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_DECLINED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + A_ACCEPTED', 'COMPLETE + A_DECLINED', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + A_ACCEPTED', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + A_CANCELLED', 'COMPLETE + A_ACCEPTED', 'COMPLETE + A_ACCEPTED', 'COMPLETE + A_ACCEPTED', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + A_ACCEPTED', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + A_DECLINED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + A_ACCEPTED', 'COMPLETE + A_ACCEPTED', 'COMPLETE + A_ACCEPTED', 'COMPLETE + W_Completer ...
#  ('START + W_Completeren aanvraag',
#   'COMPLETE + A_ACCEPTED'): ['COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_CANCELLED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + O_SELECTED', 'COMPLETE + A_FINALIZED', 'COMPLETE + O_SELECTED',  ...
#  ('COMPLETE + A_ACCEPTED', 'COMPLETE + O_SELECTED'): ['COMPLETE + A_FINALIZED',
#   'COMPLETE + A_FINALIZED',
#   'COMPLETE + A_FINALIZED',
#   'COMPLETE + A_FINALIZED',
#   'COMPLETE + A_FINALIZED',
#   'COMPLETE + A_FINALIZED',
#   'COMPLETE + A_FINALIZED',
#   'COMPLETE + A_FINALIZED',
#   'COMPLETE + A_FINALIZED',
#   'COMPLETE + A_FINALIZED',
#   'COMPLETE + A_FINALIZED',
#   'COMPLETE + A_FINALIZED',
#   'COMPLETE + A_FINALIZED',
#   'COMPLETE + A_FINALIZED',
#   'COMPLETE + A_FINALIZED',
# ...
#  ('COMPLETE + W_Nabellen offertes',
#   'SCHEDULE + W_Wijzigen contractgegevens'): ['START + W_Valideren aanvraag',
#   'SCHEDULE + W_Wijzigen contractgegevens'],
#  ('SCHEDULE + W_Wijzigen contractgegevens',
#   'START + W_Valideren aanvraag'): ['COMPLETE + W_Valideren aanvraag', 'COMPLETE + W_Valideren aanvraag'],
#  ('COMPLETE + W_Completeren aanvraag',
#   'COMPLETE + W_Nabellen offertes'): ['COMPLETE + A_CANCELLED', 'COMPLETE + A_CANCELLED', 'COMPLETE + A_CANCELLED', 'COMPLETE + O_CANCELLED', 'COMPLETE + O_CANCELLED'],
#  ('COMPLETE + A_CANCELLED',
#   'COMPLETE + W_Valideren aanvraag'): ['editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case'],
#  ('COMPLETE + W_Beoordelen fraude',
#   'SCHEDULE + W_Valideren aanvraag'): ['START + W_Valideren aanvraag', 'START + W_Valideren aanvraag', 'START + W_Valideren aanvraag', 'START + W_Valideren aanvraag'],
#  ('SCHEDULE + W_Valideren aanvraag',
#   'START + W_Valideren aanvraag'): ['SCHEDULE + W_Nabellen incomplete dossiers', 'COMPLETE + O_SELECTED', 'SCHEDULE + W_Nabellen incomplete dossiers', 'COMPLETE + W_Valideren aanvraag'],
#  ('START + W_Beoordelen fraude',
#   'SCHEDULE + W_Afhandelen leads'): ['COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude'],
#  ('SCHEDULE + W_Afhandelen leads',
#   'COMPLETE + W_Beoordelen fraude'): ['START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads', 'START + W_Afhandelen leads'],
#  ('COMPLETE + W_Beoordelen fraude',
#   'START + W_Afhandelen leads'): ['SCHEDULE + W_Beoordelen fraude', 'COMPLETE + A_PREACCEPTED', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'SCHEDULE + W_Beoordelen fraude', 'COMPLETE + W_Afhandelen leads', 'SCHEDULE + W_Beoordelen fraude', 'COMPLETE + A_PREACCEPTED', 'COMPLETE + A_PREACCEPTED', 'SCHEDULE + W_Beoordelen fraude', 'COMPLETE + A_DECLINED', 'SCHEDULE + W_Beoordelen fraude', 'COMPLETE + W_Afhandelen leads', 'SCHEDULE + W_Beoordelen fraude', 'COMPLETE + A_PREACCEPTED', 'SCHEDULE + W_Beoordelen fraude', 'COMPLETE + A_DECLINED', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + A_DECLINED', 'SCHEDULE + W_Beoordelen fraude', 'COMPLETE + A_DECLINED', 'SCHEDULE + W_Beoordelen fraude', 'COMPLETE + A_DECLINED', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + A_DECLINED', 'SCHEDULE + W_Beoordelen fraude', 'COMPLETE + A_PREACCEPTED', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + A_DECLINED', 'SCHEDULE + W_Beoordelen fraude', 'COMPLETE + W_Afhandelen leads'],
#  ('START + W_Afhandelen leads',
#   'SCHEDULE + W_Beoordelen fraude'): ['COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads', 'COMPLETE + W_Afhandelen leads'],
#  ('SCHEDULE + W_Beoordelen fraude',
#   'COMPLETE + W_Afhandelen leads'): ['START + W_Beoordelen fraude', 'START + W_Beoordelen fraude', 'START + W_Beoordelen fraude', 'START + W_Beoordelen fraude', 'START + W_Beoordelen fraude', 'START + W_Beoordelen fraude', 'START + W_Beoordelen fraude', 'START + W_Beoordelen fraude', 'START + W_Beoordelen fraude', 'START + W_Beoordelen fraude', 'START + W_Beoordelen fraude', 'START + W_Beoordelen fraude', 'START + W_Beoordelen fraude', 'START + W_Beoordelen fraude', 'START + W_Beoordelen fraude', 'START + W_Beoordelen fraude', 'START + W_Beoordelen fraude', 'START + W_Beoordelen fraude', 'START + W_Beoordelen fraude', 'START + W_Beoordelen fraude', 'START + W_Beoordelen fraude'],
#  ('COMPLETE + W_Afhandelen leads',
#   'START + W_Beoordelen fraude'): ['SCHEDULE + W_Afhandelen leads', 'COMPLETE + W_Beoordelen fraude', 'SCHEDULE + W_Afhandelen leads', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'SCHEDULE + W_Afhandelen leads', 'COMPLETE + W_Beoordelen fraude', 'SCHEDULE + W_Afhandelen leads', 'SCHEDULE + W_Afhandelen leads', 'SCHEDULE + W_Afhandelen leads', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'SCHEDULE + W_Afhandelen leads', 'SCHEDULE + W_Afhandelen leads', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'COMPLETE + W_Beoordelen fraude', 'SCHEDULE + W_Afhandelen leads', 'COMPLETE + W_Beoordelen fraude'],
#  ('START + W_Valideren aanvraag',
#   'COMPLETE + A_CANCELLED'): ['COMPLETE + O_CANCELLED', 'COMPLETE + O_CANCELLED', 'COMPLETE + O_CANCELLED', 'COMPLETE + O_CANCELLED', 'COMPLETE + O_CANCELLED', 'COMPLETE + O_CANCELLED', 'COMPLETE + O_CANCELLED', 'COMPLETE + O_CANCELLED', 'COMPLETE + O_CANCELLED', 'COMPLETE + O_CANCELLED', 'COMPLETE + O_CANCELLED', 'COMPLETE + O_CANCELLED'],
#  ('COMPLETE + O_CANCELLED',
#   'COMPLETE + W_Valideren aanvraag'): ['editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case'],
#  ('COMPLETE + A_ACCEPTED',
#   'COMPLETE + A_DECLINED'): ['COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag'],
#  ('COMPLETE + W_Nabellen incomplete dossiers',
#   'COMPLETE + A_ACTIVATED'): ['COMPLETE + A_APPROVED'],
#  ('COMPLETE + A_REGISTERED',
#   'START + W_Nabellen incomplete dossiers'): ['COMPLETE + W_Nabellen incomplete dossiers'],
#  ('COMPLETE + W_Nabellen incomplete dossiers',
#   'COMPLETE + W_Nabellen incomplete dossiers'): ['editor: close_case',
#   'COMPLETE + O_CANCELLED',
#   'COMPLETE + A_CANCELLED',
#   'COMPLETE + O_CANCELLED',
#   'COMPLETE + A_CANCELLED',
#   'START + W_Nabellen incomplete dossiers',
#   'START + W_Nabellen incomplete dossiers'],
#  ('COMPLETE + W_Beoordelen fraude',
#   'SCHEDULE + W_Completeren aanvraag'): ['START + W_Completeren aanvraag'],
#  ('START + W_Nabellen offertes',
#   'COMPLETE + O_DECLINED'): ['COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED',
#   'COMPLETE + A_DECLINED'],
#  ('COMPLETE + A_DECLINED',
#   'COMPLETE + W_Nabellen offertes'): ['editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case', 'editor: close_case'],
#  ('START + W_Nabellen incomplete dossiers',
#   'COMPLETE + A_REGISTERED'): ['COMPLETE + A_APPROVED', 'COMPLETE + A_APPROVED', 'COMPLETE + A_APPROVED', 'COMPLETE + O_ACCEPTED', 'COMPLETE + O_ACCEPTED', 'COMPLETE + A_ACTIVATED', 'COMPLETE + O_ACCEPTED', 'COMPLETE + A_APPROVED', 'COMPLETE + O_ACCEPTED', 'COMPLETE + A_APPROVED', 'COMPLETE + O_ACCEPTED', 'COMPLETE + A_APPROVED', 'COMPLETE + O_ACCEPTED', 'COMPLETE + O_ACCEPTED', 'COMPLETE + A_APPROVED', 'COMPLETE + A_APPROVED', 'COMPLETE + O_ACCEPTED', 'COMPLETE + O_ACCEPTED', 'COMPLETE + A_APPROVED'],
#  ('SCHEDULE + W_Wijzigen contractgegevens',
#   'SCHEDULE + W_Wijzigen contractgegevens'): ['START + W_Nabellen offertes',
#   'START + W_Valideren aanvraag',
#   'SCHEDULE + W_Wijzigen contractgegevens',
#   'editor: close_case',
#   'editor: close_case'],
#  ('SCHEDULE + W_Wijzigen contractgegevens',
#   'START + W_Nabellen offertes'): ['COMPLETE + O_SELECTED'],
#  ('START + W_Completeren aanvraag',
#   'COMPLETE + A_FINALIZED'): ['COMPLETE + O_SELECTED',
#   'COMPLETE + O_SELECTED',
#   'COMPLETE + O_SELECTED',
#   'COMPLETE + O_SELECTED',
#   'COMPLETE + O_SELECTED',
#   'COMPLETE + O_SELECTED',
#   'COMPLETE + O_SELECTED',
#   'COMPLETE + O_SELECTED',
#   'COMPLETE + O_SELECTED',
#   'COMPLETE + O_SELECTED',
#   'COMPLETE + O_SELECTED',
#   'COMPLETE + O_SELECTED',
#   'COMPLETE + O_SELECTED',
#   'COMPLETE + O_SELECTED',
#   'COMPLETE + O_SELECTED',
#   'COMPLETE + O_SELECTED',
#   'COMPLETE + O_SELECTED',
#   'COMPLETE + O_SELECTED',
#   'COMPLETE + O_SELECTED'],
#  ('COMPLETE + W_Valideren aanvraag',
#   'COMPLETE + W_Valideren aanvraag'): ['COMPLETE + A_APPROVED', 'editor: close_case', 'editor: close_case'],
#  ('COMPLETE + W_Valideren aanvraag',
#   'COMPLETE + A_APPROVED'): ['COMPLETE + A_ACTIVATED'],
#  ('COMPLETE + A_REGISTERED',
#   'COMPLETE + A_SUBMITTED'): ['COMPLETE + A_PARTLYSUBMITTED'],
#  ('COMPLETE + W_Nabellen incomplete dossiers',
#   'COMPLETE + O_CANCELLED'): ['COMPLETE + A_CANCELLED',
#   'COMPLETE + A_CANCELLED'],
#  ('COMPLETE + W_Valideren aanvraag',
#   'SCHEDULE + W_Nabellen incomplete dossiers'): ['START + W_Valideren aanvraag',
#   'COMPLETE + W_Valideren aanvraag',
#   'START + W_Valideren aanvraag',
#   'START + W_Valideren aanvraag',
#   'START + W_Valideren aanvraag'],
#  ('SCHEDULE + W_Nabellen incomplete dossiers',
#   'START + W_Valideren aanvraag'): ['SCHEDULE + W_Nabellen incomplete dossiers',
#   'SCHEDULE + W_Nabellen incomplete dossiers',
#   'SCHEDULE + W_Nabellen incomplete dossiers',
#   'SCHEDULE + W_Nabellen incomplete dossiers'],
#  ('COMPLETE + W_Nabellen incomplete dossiers',
#   'COMPLETE + A_CANCELLED'): ['COMPLETE + O_CANCELLED', 'COMPLETE + O_CANCELLED'],
#  ('COMPLETE + W_Nabellen offertes',
#   'COMPLETE + W_Valideren aanvraag'): ['COMPLETE + A_CANCELLED'],
#  ('COMPLETE + W_Valideren aanvraag',
#   'COMPLETE + A_CANCELLED'): ['COMPLETE + O_CANCELLED'],
#  ('COMPLETE + W_Nabellen incomplete dossiers',
#   'COMPLETE + A_APPROVED'): ['COMPLETE + A_REGISTERED'],
#  ('COMPLETE + W_Valideren aanvraag',
#   'START + W_Nabellen offertes'): ['COMPLETE + W_Nabellen offertes'],
#  ('SCHEDULE + W_Completeren aanvraag',
#   'COMPLETE + W_Completeren aanvraag'): ['COMPLETE + A_CANCELLED'],
#  ('COMPLETE + W_Nabellen incomplete dossiers',
#   'SCHEDULE + W_Wijzigen contractgegevens'): ['editor: close_case'],
#  ('COMPLETE + W_Afhandelen leads',
#   'COMPLETE + W_Afhandelen leads'): ['COMPLETE + A_CANCELLED'],
#  ('COMPLETE + W_Afhandelen leads',
#   'COMPLETE + A_CANCELLED'): ['editor: close_case'],
#  ('COMPLETE + W_Beoordelen fraude',
#   'SCHEDULE + W_Afhandelen leads'): ['START + W_Afhandelen leads'],
#  ('START + W_Beoordelen fraude',
#   'SCHEDULE + W_Completeren aanvraag'): ['COMPLETE + W_Beoordelen fraude'],
#  ('SCHEDULE + W_Completeren aanvraag',
#   'COMPLETE + W_Beoordelen fraude'): ['START + W_Completeren aanvraag'],
#  ('COMPLETE + W_Beoordelen fraude',
#   'START + W_Completeren aanvraag'): ['COMPLETE + W_Completeren aanvraag'],
#  ('COMPLETE + W_Afhandelen leads',
#   'SCHEDULE + W_Completeren aanvraag'): ['START + W_Afhandelen leads',
#   'START + W_Afhandelen leads'],
#  ('SCHEDULE + W_Completeren aanvraag',
#   'START + W_Afhandelen leads'): ['COMPLETE + W_Afhandelen leads', 'COMPLETE + A_PREACCEPTED'],
#  ('COMPLETE + W_Nabellen offertes',
#   'START + W_Completeren aanvraag'): ['COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag', 'COMPLETE + W_Completeren aanvraag'],
#  ('COMPLETE + W_Valideren aanvraag',
#   'COMPLETE + A_REGISTERED'): ['COMPLETE + A_ACTIVATED'],
#  ('COMPLETE + A_APPROVED',
#   'START + W_Valideren aanvraag'): ['COMPLETE + W_Valideren aanvraag'],
#  ('COMPLETE + O_SELECTED',
#   'SCHEDULE + W_Nabellen offertes'): ['COMPLETE + O_CREATED'],
#  ('SCHEDULE + W_Nabellen offertes',
#   'COMPLETE + O_CREATED'): ['COMPLETE + O_SENT'],
#  ('COMPLETE + O_SENT',
#   'COMPLETE + W_Completeren aanvraag'): ['START + W_Nabellen offertes'],
#  ('COMPLETE + W_Completeren aanvraag',
#   'COMPLETE + A_ACCEPTED'): ['COMPLETE + A_FINALIZED',
#   'COMPLETE + A_FINALIZED',
#   'START + W_Completeren aanvraag'],
#  ('START + W_Completeren aanvraag',
#   'START + W_Completeren aanvraag'): ['COMPLETE + W_Completeren aanvraag'],
#  ('START + W_Nabellen offertes',
#   'COMPLETE + A_SUBMITTED'): ['COMPLETE + A_PARTLYSUBMITTED'],
#  ('START + W_Valideren aanvraag',
#   'COMPLETE + A_SUBMITTED'): ['COMPLETE + A_PARTLYSUBMITTED',
#   'COMPLETE + A_PARTLYSUBMITTED'],
#  ('START + W_Nabellen incomplete dossiers',
#   'START + W_Nabellen incomplete dossiers'): ['COMPLETE + W_Nabellen incomplete dossiers'],
#  ('COMPLETE + A_ACCEPTED',
#   'START + W_Completeren aanvraag'): ['COMPLETE + W_Completeren aanvraag'],
#  ('COMPLETE + W_Completeren aanvraag',
#   'COMPLETE + O_SELECTED'): ['COMPLETE + A_FINALIZED']}

# %%
#creates a list of all concepts and a chain with only the percent chances
concepts = list(df_markov['combined_names'].unique()) + ['editor: close_case']

chain2 = {}
for i in chain:
    lister = []
    for j in concepts:
        lister.append(chain[i].count(j)/len(chain[i]))
    
    chain2[i] = np.array(lister)

# %%
timer = time.perf_counter()

df_2markov = copy.deepcopy(df_markov)
df_2markov['combined_names S1'] = df_2markov['combined_names'].shift(1) 
df_2markov.loc[0, 'combined_names S1'] = 'editor: first event'

def apply_chain(var):
    chances = chain2[(var[0], var[1])]
    cumulative_chances = chances.cumsum()
    random_number = random.uniform(0, 1)
    result = np.expand_dims(cumulative_chances, 1) >= random_number
    result_number = result.argmax()   
    return np.asarray(concepts)[result_number]

df_2prediction = copy.deepcopy(df_markov)
df_2prediction['Prediction'] =  df_2markov[['combined_names S1','combined_names']].apply(apply_chain, axis=1)

print(timer-time.perf_counter())
# Out:
# -11.122231700000157

# %%
#Prepare the next event column
df_2prediction['next_event'] = df_2prediction['combined_names']
df_2prediction.loc[df_2prediction['step_number'] == 0, 'next_event'] = 'editor: close_case'
df_2prediction['next_event'] = df_2prediction['next_event'].shift(-1)
df_2prediction.loc[len(df) - 1, 'next_event'] = 'editor: close_case'

accuracy = round((len(df_2prediction[df_2prediction['next_event'] == df_2prediction['Prediction']])/len(df_2prediction))*100, 1)
print('accuracy: ' + str(accuracy) + '%')
# Out:
# accuracy: 76.2%

# %%
df_2prediction
# Out:
#         case_id  step_number  org:resource lifecycle:transition  \
# 0             0            0         112.0             COMPLETE
# 1             0            1         112.0             COMPLETE
# 2             0            2         112.0             COMPLETE
# 3             0            3         112.0             SCHEDULE
# 4             0            4           NaN                START
# 5             0            5       10862.0             COMPLETE
# 6             0            6       10862.0             COMPLETE
# 7             0            7       10862.0             COMPLETE
# 8             0            8       10862.0             COMPLETE
# 9             0            9       10862.0             COMPLETE
# 10            0           10           NaN             SCHEDULE
# 11            0           11           NaN             COMPLETE
# 12            0           12           NaN                START
# 13            0           13           NaN             COMPLETE
# 14            0           14       10913.0                START
# 15            0           15       10913.0             COMPLETE
# 16            0           16       11049.0                START
# 17            0           17       11049.0             COMPLETE
# 18            0           18       11049.0             SCHEDULE
# 19            0           19       11049.0             COMPLETE
# 20            0           20       10629.0                START
# 21            0           21       10629.0             COMPLETE
# 22            0           22       10629.0             COMPLETE
# 23            0           23       10629.0             COMPLETE
# 24            0           24       10629.0             COMPLETE
# 25            0           25       10629.0             COMPLETE
# 26            1            0         112.0             COMPLETE
# 27            1            1         112.0             COMPLETE
# 28            1            2         112.0             COMPLETE
# 29            1            3         112.0             SCHEDULE
# ...         ...          ...           ...                  ...
# 262170    13083            2         112.0             COMPLETE
# 262171    13084            0         112.0             COMPLETE
# 262172    13084            1         112.0             COMPLETE
# 262173    13084            2         112.0             SCHEDULE
# 262174    13084            3       11169.0                START
# 262175    13084            4       11169.0             COMPLETE
# 262176    13084            5       11169.0             COMPLETE
# 262177    13085            0         112.0             COMPLETE
# 262178    13085            1         112.0             COMPLETE
# 262179    13085            2         112.0             SCHEDULE
# 262180    13085            3       11169.0                START
# 262181    13085            4       11169.0             COMPLETE
# 262182    13085            5       11169.0             SCHEDULE
# 262183    13085            6       11169.0             COMPLETE
# 262184    13085            7       10933.0                START
# 262185    13085            8       10933.0             COMPLETE
# 262186    13085            9       10933.0             COMPLETE
# 262187    13085           10       10933.0             COMPLETE
# 262188    13085           11       10933.0             COMPLETE
# 262189    13085           12       10933.0             COMPLETE
# 262190    13085           13       10933.0             SCHEDULE
# 262191    13085           14       10933.0             COMPLETE
# 262192    13085           15       11119.0                START
# 262193    13085           16       11119.0             COMPLETE
# 262194    13086            0         112.0             COMPLETE
# 262195    13086            1         112.0             COMPLETE
# 262196    13086            2         112.0             SCHEDULE
# 262197    13086            3       11169.0                START
# 262198    13086            4       11169.0             COMPLETE
# 262199    13086            5       11169.0             COMPLETE
#
#                   concept:name                    time:timestamp  \
# 0                  A_SUBMITTED  2011-10-01 00:38:44.546000+02:00
# 1            A_PARTLYSUBMITTED  2011-10-01 00:38:44.880000+02:00
# 2                A_PREACCEPTED  2011-10-01 00:39:37.906000+02:00
# 3       W_Completeren aanvraag  2011-10-01 00:39:38.875000+02:00
# 4       W_Completeren aanvraag  2011-10-01 11:36:46.437000+02:00
# 5                   A_ACCEPTED  2011-10-01 11:42:43.308000+02:00
# 6                   O_SELECTED  2011-10-01 11:45:09.243000+02:00
# 7                  A_FINALIZED  2011-10-01 11:45:09.243000+02:00
# 8                    O_CREATED  2011-10-01 11:45:11.197000+02:00
# 9                       O_SENT  2011-10-01 11:45:11.380000+02:00
# 10         W_Nabellen offertes  2011-10-01 11:45:11.554000+02:00
# 11      W_Completeren aanvraag  2011-10-01 11:45:13.917000+02:00
# 12         W_Nabellen offertes  2011-10-01 12:15:41.290000+02:00
# 13         W_Nabellen offertes  2011-10-01 12:17:08.924000+02:00
# 14         W_Nabellen offertes  2011-10-08 16:26:57.720000+02:00
# 15         W_Nabellen offertes  2011-10-08 16:32:00.886000+02:00
# 16         W_Nabellen offertes  2011-10-10 11:32:22.495000+02:00
# 17                 O_SENT_BACK  2011-10-10 11:33:03.668000+02:00
# 18        W_Valideren aanvraag  2011-10-10 11:33:04.560000+02:00
# 19         W_Nabellen offertes  2011-10-10 11:33:05.791000+02:00
# 20        W_Valideren aanvraag  2011-10-13 10:05:26.925000+02:00
# 21                A_REGISTERED  2011-10-13 10:37:29.226000+02:00
# 22                  A_APPROVED  2011-10-13 10:37:29.226000+02:00
# 23                  O_ACCEPTED  2011-10-13 10:37:29.226000+02:00
# 24                 A_ACTIVATED  2011-10-13 10:37:29.226000+02:00
# 25        W_Valideren aanvraag  2011-10-13 10:37:37.026000+02:00
# 26                 A_SUBMITTED  2011-10-01 08:08:58.256000+02:00
# 27           A_PARTLYSUBMITTED  2011-10-01 08:09:02.195000+02:00
# 28               A_PREACCEPTED  2011-10-01 08:09:56.648000+02:00
# 29      W_Completeren aanvraag  2011-10-01 08:09:59.578000+02:00
# ...                        ...                               ...
# 262170              A_DECLINED  2012-02-29 23:29:21.958000+01:00
# 262171             A_SUBMITTED  2012-02-29 23:28:55.349000+01:00
# 262172       A_PARTLYSUBMITTED  2012-02-29 23:28:55.479000+01:00
# 262173      W_Afhandelen leads  2012-02-29 23:29:06.452000+01:00
# 262174      W_Afhandelen leads  2012-03-01 09:25:39.409000+01:00
# 262175              A_DECLINED  2012-03-01 09:28:18.168000+01:00
# 262176      W_Afhandelen leads  2012-03-01 09:28:21.228000+01:00
# 262177             A_SUBMITTED  2012-02-29 23:43:09.766000+01:00
# 262178       A_PARTLYSUBMITTED  2012-02-29 23:43:09.899000+01:00
# 262179      W_Afhandelen leads  2012-02-29 23:43:54.276000+01:00
# 262180      W_Afhandelen leads  2012-03-01 09:25:47.680000+01:00
# 262181           A_PREACCEPTED  2012-03-01 09:27:50.503000+01:00
# 262182  W_Completeren aanvraag  2012-03-01 09:27:50.551000+01:00
# 262183      W_Afhandelen leads  2012-03-01 09:27:52.388000+01:00
# 262184  W_Completeren aanvraag  2012-03-01 20:11:14.761000+01:00
# 262185              A_ACCEPTED  2012-03-01 20:17:22.457000+01:00
# 262186              O_SELECTED  2012-03-01 20:22:38.593000+01:00
# 262187             A_FINALIZED  2012-03-01 20:22:38.593000+01:00
# 262188               O_CREATED  2012-03-01 20:22:40.016000+01:00
# 262189                  O_SENT  2012-03-01 20:22:40.043000+01:00
# 262190     W_Nabellen offertes  2012-03-01 20:22:40.149000+01:00
# 262191  W_Completeren aanvraag  2012-03-01 20:22:41.157000+01:00
# 262192     W_Nabellen offertes  2012-03-10 12:46:22.700000+01:00
# 262193     W_Nabellen offertes  2012-03-10 12:50:54.881000+01:00
# 262194             A_SUBMITTED  2012-02-29 23:51:16.799000+01:00
# 262195       A_PARTLYSUBMITTED  2012-02-29 23:51:17.423000+01:00
# 262196      W_Afhandelen leads  2012-02-29 23:52:01.287000+01:00
# 262197      W_Afhandelen leads  2012-03-01 09:26:46.736000+01:00
# 262198              A_DECLINED  2012-03-01 09:27:37.118000+01:00
# 262199      W_Afhandelen leads  2012-03-01 09:27:41.325000+01:00
#
#         time:weekday  time:hour                     combined_names  \
# 0                  5          0             COMPLETE + A_SUBMITTED
# 1                  5          0       COMPLETE + A_PARTLYSUBMITTED
# 2                  5          0           COMPLETE + A_PREACCEPTED
# 3                  5          0  SCHEDULE + W_Completeren aanvraag
# 4                  5         11     START + W_Completeren aanvraag
# 5                  5         11              COMPLETE + A_ACCEPTED
# 6                  5         11              COMPLETE + O_SELECTED
# 7                  5         11             COMPLETE + A_FINALIZED
# 8                  5         11               COMPLETE + O_CREATED
# 9                  5         11                  COMPLETE + O_SENT
# 10                 5         11     SCHEDULE + W_Nabellen offertes
# 11                 5         11  COMPLETE + W_Completeren aanvraag
# 12                 5         12        START + W_Nabellen offertes
# 13                 5         12     COMPLETE + W_Nabellen offertes
# 14                 5         16        START + W_Nabellen offertes
# 15                 5         16     COMPLETE + W_Nabellen offertes
# 16                 0         11        START + W_Nabellen offertes
# 17                 0         11             COMPLETE + O_SENT_BACK
# 18                 0         11    SCHEDULE + W_Valideren aanvraag
# 19                 0         11     COMPLETE + W_Nabellen offertes
# 20                 3         10       START + W_Valideren aanvraag
# 21                 3         10            COMPLETE + A_REGISTERED
# 22                 3         10              COMPLETE + A_APPROVED
# 23                 3         10              COMPLETE + O_ACCEPTED
# 24                 3         10             COMPLETE + A_ACTIVATED
# 25                 3         10    COMPLETE + W_Valideren aanvraag
# 26                 5          8             COMPLETE + A_SUBMITTED
# 27                 5          8       COMPLETE + A_PARTLYSUBMITTED
# 28                 5          8           COMPLETE + A_PREACCEPTED
# 29                 5          8  SCHEDULE + W_Completeren aanvraag
# ...              ...        ...                                ...
# 262170             2         23              COMPLETE + A_DECLINED
# 262171             2         23             COMPLETE + A_SUBMITTED
# 262172             2         23       COMPLETE + A_PARTLYSUBMITTED
# 262173             2         23      SCHEDULE + W_Afhandelen leads
# 262174             3          9         START + W_Afhandelen leads
# 262175             3          9              COMPLETE + A_DECLINED
# 262176             3          9      COMPLETE + W_Afhandelen leads
# 262177             2         23             COMPLETE + A_SUBMITTED
# 262178             2         23       COMPLETE + A_PARTLYSUBMITTED
# 262179             2         23      SCHEDULE + W_Afhandelen leads
# 262180             3          9         START + W_Afhandelen leads
# 262181             3          9           COMPLETE + A_PREACCEPTED
# 262182             3          9  SCHEDULE + W_Completeren aanvraag
# 262183             3          9      COMPLETE + W_Afhandelen leads
# 262184             3         20     START + W_Completeren aanvraag
# 262185             3         20              COMPLETE + A_ACCEPTED
# 262186             3         20              COMPLETE + O_SELECTED
# 262187             3         20             COMPLETE + A_FINALIZED
# 262188             3         20               COMPLETE + O_CREATED
# 262189             3         20                  COMPLETE + O_SENT
# 262190             3         20     SCHEDULE + W_Nabellen offertes
# 262191             3         20  COMPLETE + W_Completeren aanvraag
# 262192             5         12        START + W_Nabellen offertes
# 262193             5         12     COMPLETE + W_Nabellen offertes
# 262194             2         23             COMPLETE + A_SUBMITTED
# 262195             2         23       COMPLETE + A_PARTLYSUBMITTED
# 262196             2         23      SCHEDULE + W_Afhandelen leads
# 262197             3          9         START + W_Afhandelen leads
# 262198             3          9              COMPLETE + A_DECLINED
# 262199             3          9      COMPLETE + W_Afhandelen leads
#
#                                Prediction                         next_event
# 0            COMPLETE + A_PARTLYSUBMITTED       COMPLETE + A_PARTLYSUBMITTED
# 1                COMPLETE + A_PREACCEPTED           COMPLETE + A_PREACCEPTED
# 2       SCHEDULE + W_Completeren aanvraag  SCHEDULE + W_Completeren aanvraag
# 3          START + W_Completeren aanvraag     START + W_Completeren aanvraag
# 4       COMPLETE + W_Completeren aanvraag              COMPLETE + A_ACCEPTED
# 5                  COMPLETE + A_FINALIZED              COMPLETE + O_SELECTED
# 6                  COMPLETE + A_FINALIZED             COMPLETE + A_FINALIZED
# 7                    COMPLETE + O_CREATED               COMPLETE + O_CREATED
# 8                       COMPLETE + O_SENT                  COMPLETE + O_SENT
# 9          SCHEDULE + W_Nabellen offertes     SCHEDULE + W_Nabellen offertes
# 10      COMPLETE + W_Completeren aanvraag  COMPLETE + W_Completeren aanvraag
# 11            START + W_Nabellen offertes        START + W_Nabellen offertes
# 12                 COMPLETE + O_CANCELLED     COMPLETE + W_Nabellen offertes
# 13            START + W_Nabellen offertes        START + W_Nabellen offertes
# 14                 COMPLETE + O_CANCELLED     COMPLETE + W_Nabellen offertes
# 15            START + W_Nabellen offertes        START + W_Nabellen offertes
# 16         COMPLETE + W_Nabellen offertes             COMPLETE + O_SENT_BACK
# 17        SCHEDULE + W_Valideren aanvraag    SCHEDULE + W_Valideren aanvraag
# 18         COMPLETE + W_Nabellen offertes     COMPLETE + W_Nabellen offertes
# 19           START + W_Valideren aanvraag       START + W_Valideren aanvraag
# 20        COMPLETE + W_Valideren aanvraag            COMPLETE + A_REGISTERED
# 21                  COMPLETE + A_APPROVED              COMPLETE + A_APPROVED
# 22                 COMPLETE + A_ACTIVATED              COMPLETE + O_ACCEPTED
# 23                 COMPLETE + A_ACTIVATED             COMPLETE + A_ACTIVATED
# 24        COMPLETE + W_Valideren aanvraag    COMPLETE + W_Valideren aanvraag
# 25                     editor: close_case                 editor: close_case
# 26           COMPLETE + A_PARTLYSUBMITTED       COMPLETE + A_PARTLYSUBMITTED
# 27          SCHEDULE + W_Afhandelen leads           COMPLETE + A_PREACCEPTED
# 28      SCHEDULE + W_Completeren aanvraag  SCHEDULE + W_Completeren aanvraag
# 29         START + W_Completeren aanvraag     START + W_Completeren aanvraag
# ...                                   ...                                ...
# 262170                 editor: close_case                 editor: close_case
# 262171       COMPLETE + A_PARTLYSUBMITTED       COMPLETE + A_PARTLYSUBMITTED
# 262172      SCHEDULE + W_Afhandelen leads      SCHEDULE + W_Afhandelen leads
# 262173         START + W_Afhandelen leads         START + W_Afhandelen leads
# 262174           COMPLETE + A_PREACCEPTED              COMPLETE + A_DECLINED
# 262175      COMPLETE + W_Afhandelen leads      COMPLETE + W_Afhandelen leads
# 262176                 editor: close_case                 editor: close_case
# 262177       COMPLETE + A_PARTLYSUBMITTED       COMPLETE + A_PARTLYSUBMITTED
# 262178           COMPLETE + A_PREACCEPTED      SCHEDULE + W_Afhandelen leads
# 262179         START + W_Afhandelen leads         START + W_Afhandelen leads
# 262180           COMPLETE + A_PREACCEPTED           COMPLETE + A_PREACCEPTED
# 262181  SCHEDULE + W_Completeren aanvraag  SCHEDULE + W_Completeren aanvraag
# 262182     START + W_Completeren aanvraag      COMPLETE + W_Afhandelen leads
# 262183     START + W_Completeren aanvraag     START + W_Completeren aanvraag
# 262184  COMPLETE + W_Completeren aanvraag              COMPLETE + A_ACCEPTED
# 262185              COMPLETE + O_SELECTED              COMPLETE + O_SELECTED
# 262186             COMPLETE + A_FINALIZED             COMPLETE + A_FINALIZED
# 262187               COMPLETE + O_CREATED               COMPLETE + O_CREATED
# 262188                  COMPLETE + O_SENT                  COMPLETE + O_SENT
# 262189     SCHEDULE + W_Nabellen offertes     SCHEDULE + W_Nabellen offertes
# 262190  COMPLETE + W_Completeren aanvraag  COMPLETE + W_Completeren aanvraag
# 262191        START + W_Nabellen offertes        START + W_Nabellen offertes
# 262192     COMPLETE + W_Nabellen offertes     COMPLETE + W_Nabellen offertes
# 262193        START + W_Nabellen offertes                 editor: close_case
# 262194       COMPLETE + A_PARTLYSUBMITTED       COMPLETE + A_PARTLYSUBMITTED
# 262195      SCHEDULE + W_Afhandelen leads      SCHEDULE + W_Afhandelen leads
# 262196         START + W_Afhandelen leads         START + W_Afhandelen leads
# 262197              COMPLETE + A_DECLINED              COMPLETE + A_DECLINED
# 262198      COMPLETE + W_Afhandelen leads      COMPLETE + W_Afhandelen leads
# 262199                 editor: close_case                 editor: close_case
#
# [262200 rows x 11 columns]

# %%
#shows which predictions are given too much (>1) and which too little (<1)
predicted_correct_events = Counter(list(df_2prediction[df_2prediction['next_event'] == df_2prediction['Prediction']]['Prediction']))
predicted_events = Counter(list(df_2prediction['Prediction']))
true_events = Counter(list(df_2prediction['next_event']))

for i in predicted_events:
    if i != i:
        break
    print(i)
    per = round(predicted_events[i]/true_events[i]*100, 1)
    print(str(per) + '%')
    if per > 100:
        print('given ' + str(round(per-100, 1)) + '% too much')
    
    elif per < 100:
        print('given ' + str(round(100-per, 1)) + '% too little')
    
    else:
        print('given exactly the right amount')
   
    print('')
# Out:
# COMPLETE + A_PARTLYSUBMITTED
# 100.0%
# given exactly the right amount
#
# COMPLETE + A_PREACCEPTED
# 99.1%
# given 0.9% too little
#
# SCHEDULE + W_Completeren aanvraag
# 100.0%
# given exactly the right amount
#
# START + W_Completeren aanvraag
# 100.0%
# given exactly the right amount
#
# COMPLETE + W_Completeren aanvraag
# 100.1%
# given 0.1% too much
#
# COMPLETE + A_FINALIZED
# 99.4%
# given 0.6% too little
#
# COMPLETE + O_CREATED
# 100.0%
# given exactly the right amount
#
# COMPLETE + O_SENT
# 100.0%
# given exactly the right amount
#
# SCHEDULE + W_Nabellen offertes
# 100.3%
# given 0.3% too much
#
# START + W_Nabellen offertes
# 99.9%
# given 0.1% too little
#
# COMPLETE + O_CANCELLED
# 99.9%
# given 0.1% too little
#
# COMPLETE + W_Nabellen offertes
# 100.1%
# given 0.1% too much
#
# SCHEDULE + W_Valideren aanvraag
# 100.6%
# given 0.6% too much
#
# START + W_Valideren aanvraag
# 100.1%
# given 0.1% too much
#
# COMPLETE + W_Valideren aanvraag
# 100.2%
# given 0.2% too much
#
# COMPLETE + A_APPROVED
# 98.6%
# given 1.4% too little
#
# COMPLETE + A_ACTIVATED
# 98.5%
# given 1.5% too little
#
# editor: close_case
# 100.0%
# given exactly the right amount
#
# SCHEDULE + W_Afhandelen leads
# 100.4%
# given 0.4% too much
#
# COMPLETE + A_ACCEPTED
# 99.6%
# given 0.4% too little
#
# COMPLETE + O_SELECTED
# 99.4%
# given 0.6% too little
#
# COMPLETE + O_SENT_BACK
# 98.1%
# given 1.9% too little
#
# COMPLETE + W_Nabellen incomplete dossiers
# 99.5%
# given 0.5% too little
#
# COMPLETE + A_REGISTERED
# 102.8%
# given 2.8% too much
#
# SCHEDULE + W_Nabellen incomplete dossiers
# 98.9%
# given 1.1% too little
#
# COMPLETE + O_ACCEPTED
# 100.9%
# given 0.9% too much
#
# SCHEDULE + W_Wijzigen contractgegevens
# 83.3%
# given 16.7% too little
#
# COMPLETE + A_DECLINED
# 101.1%
# given 1.1% too much
#
# COMPLETE + A_CANCELLED
# 101.6%
# given 1.6% too much
#
# START + W_Afhandelen leads
# 100.0%
# given exactly the right amount
#
# COMPLETE + W_Afhandelen leads
# 100.7%
# given 0.7% too much
#
# COMPLETE + O_DECLINED
# 100.7%
# given 0.7% too much
#
# START + W_Nabellen incomplete dossiers
# 100.0%
# given exactly the right amount
#
# START + W_Beoordelen fraude
# 99.3%
# given 0.7% too little
#
# COMPLETE + W_Beoordelen fraude
# 100.0%
# given exactly the right amount
#
# SCHEDULE + W_Beoordelen fraude
# 101.6%
# given 1.6% too much
